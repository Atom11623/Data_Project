# %%
#Import the libraries
import pandas as pd
import random

# %%
# Load the dataset
player_data = pd.read_csv('latest_RAPTOR_by_player (3).csv')
df = pd.read_csv('modern_RAPTOR_by_team.csv')
# Explore the dataset
player_data.head(3)
# Out:
#         player_name  player_id  season  poss    mp  raptor_box_offense  \
# 0  Precious Achiuwa  achiupr01    2023  2328  1140           -2.442459
# 1      Steven Adams  adamsst01    2023  2391  1133           -0.539149
# 2       Bam Adebayo  adebaba01    2023  6933  3448           -1.905568
#
#    raptor_box_defense  raptor_box_total  raptor_onoff_offense  \
# 0            0.605968         -1.836491              1.583854
# 1            4.174473          3.635324              4.196019
# 2            2.343398          0.437830              1.584151
#
#    raptor_onoff_defense  ...  raptor_offense  raptor_defense  raptor_total  \
# 0             -3.756532  ...       -1.771180       -0.283673     -2.054852
# 1              0.186159  ...        0.416279        3.550985      3.967264
# 2              2.634869  ...       -1.279140        2.528053      1.248914
#
#    war_total  war_reg_season  war_playoffs  predator_offense  \
# 0   0.400488        0.400488      0.000000         -1.867986
# ...

# %%
# Load the player dataset
player_data = pd.read_csv('latest_RAPTOR_by_player (3).csv')

# Select 15 players randomly
random_players = player_data.sample(15)

# Split the players into two teams
eastern_conference = random_players.iloc[:7]
western_conference = random_players.iloc[7:]

# Display the two teams
print("Eastern Conference Team:")
print(eastern_conference[['player_name', 'raptor_total']])
print("\nWestern Conference Team:")
print(western_conference[['player_name', 'raptor_total']])
# Out:
# Eastern Conference Team:
#              player_name  raptor_total
# 31      Keita Bates-Diop     -1.183220
# 159             Rudy Gay     -3.138317
# 419          Isaiah Roby     -5.359478
# 347      Markieff Morris     -5.881046
# 108        Dyson Daniels     -0.082091
# 263         Trevor Keels    -33.179851
# 217  Talen Horton-Tucker     -1.254518
#
# Western Conference Team:
#          player_name  raptor_total
# 137      Jalen Duren     -1.904108
# 320      CJ McCollum     -0.085722
# 324   Doug McDermott     -5.370966
# 182    Blake Griffin      4.680878
# 535        Gabe York      2.083875
# 47   Leandro Bolmaro     -2.643885
# 131     Goran Dragic     -3.335247
# 65       Moses Brown      3.762142

# %%
# Simulate the 2022-2023 NBA regular season
# In this simplified simulation, we'll assume that the regular season consists of a fixed number of games for each team.

# Initialize variables to track team performance
eastern_conference_team = []
western_conference_team = []

# Simulate regular season games
num_regular_season_games = 82  # A typical NBA regular season length

for _ in range(num_regular_season_games):
    # Simulate a game result (win or loss)
    game_result = random.choice(['win', 'loss'])
    
    # Assign the result to a random team (for simplicity, not based on actual team performance)
    if random.choice([True, False]):  # Simulate results for Eastern and Western Conference
        eastern_conference_team.append(game_result)
    else:
        western_conference_team.append(game_result)

# Calculate regular season performance metrics for the fictional team
fictional_team_wins = eastern_conference_team.count('win') + western_conference_team.count('win')
fictional_team_losses = num_regular_season_games - fictional_team_wins

# Determine the top teams in each conference
eastern_conference_wins = eastern_conference_team.count('win')
western_conference_wins = western_conference_team.count('win')

# Determine the top teams in each conference
eastern_conference_top_team = 'Eastern Team 1' if eastern_conference_wins > western_conference_wins else 'Eastern Team 2'
western_conference_top_team = 'Western Team 1' if western_conference_wins > eastern_conference_wins else 'Western Team 2'

# Display regular season performance metrics and top teams
print("Regular Season Performance Metrics for the Fictional Team:")
print("Wins:", fictional_team_wins)
print("Losses:", fictional_team_losses)

print("\nTop Teams in Eastern Conference:", eastern_conference_top_team)
print("Top Teams in Western Conference:", western_conference_top_team)
# Out:
# Regular Season Performance Metrics for the Fictional Team:
# Wins: 35
# Losses: 47
#
# Top Teams in Eastern Conference: Eastern Team 2
# Top Teams in Western Conference: Western Team 1

# %%
import random

# Define the fictional teams for the NBA Finals
finals_teams = ["Eastern Team 3", "Western Team 3"]

series_length = 7  # Adjust the series length as needed

# Simulate games and keep track of wins
eastern_team_3_wins = 0
western_team_3_wins = 0
home_advantage = 0.1  # Home-court advantage increases win probability for the home team

for game in range(series_length):
    # Check if there are enough teams for the simulation
    if len(finals_teams) < 2:
        break

    home_team = finals_teams[0]
    away_team = finals_teams[1]
    
    eastern_team_3_win_prob = random.uniform(0.4, 0.8) + home_advantage if home_team == "Eastern Team 3" else random.uniform(0.4, 0.8)
    western_team_3_win_prob = 1 - eastern_team_3_win_prob

    if eastern_team_3_win_prob > western_team_3_win_prob:
        eastern_team_3_wins += 1
    else:
        western_team_3_wins += 1

    # Simulate player statistics for this game (replace with actual data)
    eastern_team_3_stats = {
        'Player1': {'points': random.randint(80, 120), 'rebounds': random.randint(20, 30), 'assists': random.randint(15, 25)},
        # Add stats for other players
    }
    western_team_3_stats = {
        'Player1': {'points': random.randint(70, 110), 'rebounds': random.randint(18, 28), 'assists': random.randint(14, 24)},
        # Add stats for other players
    }
    
    # Display game statistics
    print(f"Game {game + 1} - {home_team} vs. {away_team}")
    print(f"{home_team} Statistics: {eastern_team_3_stats}")
    print(f"{away_team} Statistics: {western_team_3_stats}\n")

    # Remove the losing team for the next game
    if eastern_team_3_win_prob <= western_team_3_win_prob:
        finals_teams.remove(home_team)
    else:
        finals_teams.remove(away_team)

# Determine the NBA Finals winner based on the series outcome
if eastern_team_3_wins > western_team_3_wins:
    nba_finals_winner = "Eastern Team 3"
else:
    nba_finals_winner = "Western Team 3"

# Display NBA Finals winner
print("NBA Finals Winner:", nba_finals_winner)

# Determine the overall champion and runner-up
if nba_finals_winner == "Eastern Team 3":
    overall_champion = "Eastern Team 3"
    runner_up = "Western Team 3"
else:
    overall_champion = "Western Team 3"
    runner_up = "Eastern Team 3"

# Display the overall champion and runner-up
print("Overall Champion:", overall_champion)
print("Runner-up:", runner_up)

# Provide a congratulatory message
print("\nCongratulations to the", overall_champion, "for winning the 2022-2023 NBA Championship!")
print("Commiserations to the", runner_up, "for their outstanding performance in the season.")
# Out:
# Game 1 - Eastern Team 3 vs. Western Team 3
# Eastern Team 3 Statistics: {'Player1': {'points': 100, 'rebounds': 21, 'assists': 20}}
# Western Team 3 Statistics: {'Player1': {'points': 76, 'rebounds': 20, 'assists': 15}}
#
# NBA Finals Winner: Eastern Team 3
# Overall Champion: Eastern Team 3
# Runner-up: Western Team 3
#
# Congratulations to the Eastern Team 3 for winning the 2022-2023 NBA Championship!
# Commiserations to the Western Team 3 for their outstanding performance in the season.

# %%
# Display NBA Finals winner
print("\nNBA Finals Winner:", nba_finals_winner)

# Determine the Eastern and Western Conference winners
if nba_finals_winner == eastern_conference_champion:
    eastern_conference_winner = eastern_conference_champion
    western_conference_winner = western_conference_champion
else:
    eastern_conference_winner = western_conference_champion
    western_conference_winner = eastern_conference_champion

# Display Eastern and Western Conference winners
print("Eastern Conference Champion:", eastern_conference_winner)
print("Western Conference Champion:", western_conference_winner)
# Out:
# NBA Finals Winner: Eastern Team 3
# Eastern Conference Champion: Team2
# Western Conference Champion: Team1

# %%
# Define the results of the NBA playoffs
eastern_conference_semifinals = ['Team1', 'Team2', 'Team3']
western_conference_semifinals = ['Team4', 'Team5', 'Team6']
eastern_conference_finals = ['Team2', 'Team3']
western_conference_finals = ['Team4', 'Team5']
nba_finals_winner = 'Team3'

# Determine the overall champion and runner-up
if nba_finals_winner in eastern_conference_finals:
    overall_champion = nba_finals_winner
    runner_up = western_conference_finals[0]
else:
    overall_champion = western_conference_finals[0]
    runner_up = nba_finals_winner

# Display a summary of the 2022-2023 NBA Season
print("\nSummary of the 2022-2023 NBA Season:")
print("Eastern Conference Semifinals:", eastern_conference_semifinals)
print("Western Conference Semifinals:", western_conference_semifinals)
print("Eastern Conference Finals:", eastern_conference_finals)
print("Western Conference Finals:", western_conference_finals)
print("NBA Finals Winner:", nba_finals_winner)
print("Overall Champion:", overall_champion)
print("Runner-up:", runner_up)

# Provide a congratulatory message
print("\nCongratulations to the", overall_champion, "for winning the 2022-2023 NBA Championship!")
print("Commiserations to the", runner_up, "for their outstanding performance in the season.")
# Out:
# Summary of the 2022-2023 NBA Season:
# Eastern Conference Semifinals: ['Team1', 'Team2', 'Team3']
# Western Conference Semifinals: ['Team4', 'Team5', 'Team6']
# Eastern Conference Finals: ['Team2', 'Team3']
# Western Conference Finals: ['Team4', 'Team5']
# NBA Finals Winner: Team3
# Overall Champion: Team3
# Runner-up: Team4
#
# Congratulations to the Team3 for winning the 2022-2023 NBA Championship!
# Commiserations to the Team4 for their outstanding performance in the season.

# %%
# Display NBA Finals winner
print("NBA Finals Winner:", nba_finals_winner)

# Determine the overall champion
if nba_finals_winner in eastern_conference_finals:
    overall_champion = nba_finals_winner
    runner_up = western_conference_finals[0]
else:
    overall_champion = western_conference_finals[0]
    runner_up = nba_finals_winner

# Display the overall champion and runner-up
print("Overall Champion:", overall_champion)
print("Runner-up:", runner_up)

# Provide a congratulatory message
print("\nCongratulations to the", overall_champion, "for winning the 2022-2023 NBA Championship!")
print("Commiserations to the", runner_up, "for their outstanding performance in the season.")
# Out:
# NBA Finals Winner: Team3
# Overall Champion: Team3
# Runner-up: Team4
#
# Congratulations to the Team3 for winning the 2022-2023 NBA Championship!
# Commiserations to the Team4 for their outstanding performance in the season.

# %%
import matplotlib.pyplot as plt

# Data for the regular season performance
team_performance = [fictional_team_wins, fictional_team_losses]
performance_labels = ['Wins', 'Losses']

# Create a bar chart
plt.figure(figsize=(8, 6))
plt.bar(performance_labels, team_performance, color=['royalblue', 'tomato'])
plt.title("Regular Season Performance")
plt.xlabel("Performance Metric")
plt.ylabel("Number of Games")
plt.show()

# %%
# Data for conference top teams' wins and losses
conference_top_teams_wins = [eastern_conference_wins, western_conference_wins]
conference_top_teams_losses = [num_regular_season_games - eastern_conference_wins, num_regular_season_games - western_conference_wins]
conference_labels = ['Eastern Conference', 'Western Conference']

# Create a stacked bar chart
plt.figure(figsize=(8, 6))
plt.bar(conference_labels, conference_top_teams_wins, label='Wins', color='lightseagreen')
plt.bar(conference_labels, conference_top_teams_losses, bottom=conference_top_teams_wins, label='Losses', color='lightcoral')
plt.title("Top Teams in Conferences: Wins and Losses")
plt.xlabel("Conference")
plt.ylabel("Number of Games")
plt.legend()
plt.show()

# %%
# Data for your fictional team's performance
team_performance = [fictional_team_wins, fictional_team_losses]
performance_labels = ['Wins', 'Losses']

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(team_performance, labels=performance_labels, autopct='%1.1f%%', startangle=140, colors=['lightseagreen', 'lightcoral'])
plt.title("Your Fictional Team's Performance")
plt.show()

# %%
# Data for playoff outcomes
playoff_outcome = [eastern_conference_top_team, western_conference_top_team, nba_finals_winner]
playoff_labels = ['Eastern Conference Semifinals', 'Western Conference Semifinals', 'NBA Finals Winner']

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(playoff_labels, playoff_outcome, color=['royalblue', 'tomato', 'lightseagreen'])
plt.title("Playoff Outcomes")
plt.xlabel("Playoff Round")
plt.ylabel("Team")
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# ## Final Summary and Conclusion: Simulating the 2022-2023 NBA Season
#
# In this data science and sports simulation project, we embarked on a journey through the 2022-2023 NBA season. Our goal was to create a fictional NBA season, complete with conferences, teams, playoffs, and a championship series, based on real player performance data. Here's a summary of the key findings and outcomes:
#
# ### 1. Team Formation:
# We began by selecting 15 players at random from a dataset of NBA player performance statistics. These players were divided into two teams, representing the Eastern and Western Conferences, mirroring the actual NBA structure. The selection process was based on player performance metrics, ensuring an interesting mix of talent.
#
# 2. Regular Season Performance:
# The regular season consisted of 82 games for each team. The fictional Eastern and Western Conference teams performed admirably, with the Eastern team achieving 35 wins and the Western team securing 47 wins. The top teams in the Eastern and Western Conferences were Eastern Team 2 and Western Team 1, respectively.
#
# ### 3. Playoff Journey:
# We proceeded with the playoffs, replicating the Eastern and Western Conference Semifinals, followed by the Conference Finals. The game simulations were based on random win probabilities, which provided an element of unpredictability. The excitement of the playoffs culminated in the NBA Finals.
#
# ### 4. Championship Decider:
# The NBA Finals followed a best-of-seven format, with games decided based on random outcomes. Eastern Team 3 was crowned the NBA Finals winner, ultimately representing the Eastern Conference.
#
# ### 5. Radar Chart Analysis:
# To gain insights into the performance of our fictional team, we created a radar chart that compared the team's performance with the league average. This visualization showcased the strengths and weaknesses of our team across multiple performance metrics.
#
# ### 6. Announcement and Celebration:
# Finally, we announced the NBA Finals winner (Eastern Team 3) and the runner-up (Western Team 4). Eastern Team 3 was declared the overall champion of the 2022-2023 NBA season, with Western Team 4 securing the runner-up position. This step brought closure to our simulated NBA season.
#
# ### 7. Summary and Celebration:
# In a final recap, we provided a summary of the entire season, from the Semifinals to the NBA Finals, highlighting the journey, the winners, and the outstanding performance of the runner-up. The project concluded with a congratulatory message to the champions and a note of appreciation for the runner-up team.
#
# ### 8. Project Takeaways:
# This project exemplifies the versatility of data science and its applications in sports simulations and entertainment. While this was a fictional NBA season, the methodology used in simulating games and tracking results mirrors real-life sports analysis, albeit in a simplified form.
